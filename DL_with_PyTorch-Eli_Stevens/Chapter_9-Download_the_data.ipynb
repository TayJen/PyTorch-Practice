# %% [markdown]
# We will start with moving to the book's directory

# %%
# %cd /content/drive/Shareddrives/data_drive/DL_with_PyTorch-Eli_Stevens
# %pwd
# Out:
# /content/drive/Shareddrives/data_drive/DL_with_PyTorch-Eli_Stevens
# '/content/drive/Shareddrives/data_drive/DL_with_PyTorch-Eli_Stevens'

# %%
# !ls
# Out:
# data

# %% [markdown]
# ## Download the data

# %%
# !pip install --quiet wget

# %%
from tqdm import tqdm
import wget


data_links = [
    'https://zenodo.org/record/3723295/files/subset0.zip',
    'https://zenodo.org/record/3723295/files/subset1.zip',
    'https://zenodo.org/record/3723295/files/subset2.zip',
    'https://zenodo.org/record/3723295/files/subset3.zip',
    'https://zenodo.org/record/3723295/files/subset4.zip',
    'https://zenodo.org/record/3723295/files/subset5.zip',
    'https://zenodo.org/record/3723295/files/subset6.zip',
    'https://zenodo.org/record/4121926/files/subset7.zip',
    'https://zenodo.org/record/4121926/files/subset8.zip',
    'https://zenodo.org/record/4121926/files/subset9.zip'
]

ann_link = 'https://zenodo.org/record/3723295/files/annotations.csv'
cands_link = 'https://zenodo.org/record/3723295/files/candidates.csv'

# %% [markdown]
# ### Annotations & candidates

# %%
wget.download(ann_link)
# Out:
# 'annotations.csv'

# %%
wget.download(cands_link)
# Out:
# 'candidates.csv'

# %% [markdown]
# ### Subsets

# %%
from urllib.request import urlretrieve


url = data_links[0]
dst = './data/zipped/subset0.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset0.zip', <http.client.HTTPMessage at 0x7f09a63f5350>)

# %%
url = data_links[1]
dst = './data/zipped/subset1.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset1.zip', <http.client.HTTPMessage at 0x7f09a6418390>)

# %%
url = data_links[2]
dst = './data/zipped/subset2.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset2.zip', <http.client.HTTPMessage at 0x7f09a6373690>)

# %%
url = data_links[3]
dst = './data/zipped/subset3.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset3.zip', <http.client.HTTPMessage at 0x7f09a644fb10>)

# %%
url = data_links[4]
dst = './data/zipped/subset4.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset4.zip', <http.client.HTTPMessage at 0x7f09a64184d0>)

# %%
url = data_links[5]
dst = './data/zipped/subset5.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset5.zip', <http.client.HTTPMessage at 0x7f09a6715b50>)

# %%
url = data_links[6]
dst = './data/zipped/subset6.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset6.zip', <http.client.HTTPMessage at 0x7f09a6352fd0>)

# %%
url = data_links[7]
dst = './data/zipped/subset7.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset7.zip', <http.client.HTTPMessage at 0x7f09a63526d0>)

# %%
url = data_links[8]
dst = './data/zipped/subset8.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset8.zip', <http.client.HTTPMessage at 0x7f09a646c090>)

# %%
url = data_links[9]
dst = './data/zipped/subset9.zip'
urlretrieve(url, dst)
# Out:
# ('./data/zipped/subset9.zip', <http.client.HTTPMessage at 0x7f09a6452fd0>)

# %% [markdown]
# ### Checking

# %%
import os

os.listdir('./data'), os.listdir('./data/zipped')
# Out:
# (['zipped', 'annotations.csv', 'candidates.csv', 'unzipped'],
#  ['subset0.zip',
#   'subset1.zip',
#   'subset2.zip',
#   'subset3.zip',
#   'subset4.zip',
#   'subset5.zip',
#   'subset6.zip',
#   'subset7.zip',
#   'subset8.zip',
#   'subset9.zip'])

# %% [markdown]
# ## Unzipping

# %%
!7z x ./data/zipped/subset0.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6811924508 bytes (6497 MiB)
#
# Extracting archive: ./data/zipped/subset0.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset0.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6811924508
# 64-bit = +
#
# 100% 177 - subset0/1.3.6.1.4.1.14519.5.2 . 83010707182900091062408058.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset1.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6334778552 bytes (6042 MiB)
#
# Extracting archive: ./data/zipped/subset1.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset1.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6334778552
# 64-bit = +
#
# 100% 177 - subset1/1.3.6.1.4.1.14519.5.2 . 64865033574190975654369557.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset2.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 7257937108 bytes (6922 MiB)
#
# Extracting archive: ./data/zipped/subset2.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset2.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 7257937108
# 64-bit = +
#
# 100% 177 - subset2/1.3.6.1.4.1.14519.5.2 . 52370561266624992539111877.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset3.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6896620114 bytes (6578 MiB)
#
# Extracting archive: ./data/zipped/subset3.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset3.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6896620114
# 64-bit = +
#
# 100% 177 - subset3/1.3.6.1.4.1.14519.5.2 . 26625618184773401026809852.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset4.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6856144330 bytes (6539 MiB)
#
# Extracting archive: ./data/zipped/subset4.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset4.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6856144330
# 64-bit = +
#
# 100% 177 - subset4/1.3.6.1.4.1.14519.5.2 . 35939545691201820711078950.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset5.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6610460097 bytes (6305 MiB)
#
# Extracting archive: ./data/zipped/subset5.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset5.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6610460097
# 64-bit = +
#
# 100% 177 - subset5/1.3.6.1.4.1.14519.5.2 . 11151772797848993829243183.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset6.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6531050274 bytes (6229 MiB)
#
# Extracting archive: ./data/zipped/subset6.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset6.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6531050274
# 64-bit = +
#
# 100% 177 - subset6/1.3.6.1.4.1.14519.5.2 . 88628308192728558382581802.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset7.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6313598213 bytes (6022 MiB)
#
# Extracting archive: ./data/zipped/subset7.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset7.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6313598213
# 64-bit = +
#
# 100% 177 - subset7/1.3.6.1.4.1.14519.5.2 . 59772950022352718462251777.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset8.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6025767505 bytes (5747 MiB)
#
# Extracting archive: ./data/zipped/subset8.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset8.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6025767505
# 64-bit = +
#
# 100% 175 - subset8/1.3.6.1.4.1.14519.5.2 . 11074084993415992563148335.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %%
!7z x ./data/zipped/subset9.zip -o./data/unzipped
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6699650017 bytes (6390 MiB)
#
# Extracting archive: ./data/zipped/subset9.zip
#
# ERRORS:
# Headers Error
#
# --
# Path = ./data/zipped/subset9.zip
# Type = zip
# ERRORS:
# Headers Error
# Physical Size = 6699650017
# 64-bit = +
#
# 100% 175 - subset9/1.3.6.1.4.1.14519.5.2 . 29570505893110165820050204.raw
#
# Archives with Errors: 1
#
# Open Errors: 1

# %% [markdown]
# ## Checking

# %%
os.listdir('./data/unzipped')
# Out:
# ['subset0',
#  'subset1',
#  'subset2',
#  'subset3',
#  'subset4',
#  'subset5',
#  'subset6',
#  'subset7',
#  'subset8',
#  'subset9']

# %%
len(os.listdir('./data/unzipped/subset0')), \
len(os.listdir('./data/unzipped/subset1')), \
len(os.listdir('./data/unzipped/subset2')), \
len(os.listdir('./data/unzipped/subset3')), \
len(os.listdir('./data/unzipped/subset4')), \
len(os.listdir('./data/unzipped/subset5')), \
len(os.listdir('./data/unzipped/subset6')), \
len(os.listdir('./data/unzipped/subset7')), \
len(os.listdir('./data/unzipped/subset8')), \
len(os.listdir('./data/unzipped/subset9'))
# Out:
# (178, 178, 178, 178, 178, 178, 178, 178, 176, 176)
